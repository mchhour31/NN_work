# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Task 1: Recording the Data
#
# I will use my mobile device, Samsung S20 which will be located in my front pocket during measurements.
#
# __Activity:__
# - Burpees in my room, recorded for 3 minutes
# - Jumping Jacks in my room, recorded for 3 minutes

# %% [markdown]
# ## Task 2: Formatting the Data

# %%
burpee = pd.read_csv("Burpees.csv").round(decimals=2)
jump = pd.read_csv("Jumping.csv").round(decimals=2)

burpee.rename(columns={"ax (m/s^2)": "ax", "ay (m/s^2)": "ay", "az (m/s^2)": "az", "aT (m/s^2)": "|a|"}, inplace=True)
jump.rename(columns={"ax (m/s^2)": "ax", "ay (m/s^2)": "ay", "az (m/s^2)": "az", "aT (m/s^2)": "|a|"}, inplace=True)

burpee
# Out:
#                 time    ax    ay    az   |a|
# 0      23:27:29:8510 -1.30 -0.08  1.80  2.22
# 1      23:27:29:8610 -1.03  0.09  1.22  1.60
# 2      23:27:29:8670 -0.77  0.28  0.03  0.82
# 3      23:27:29:8780 -0.47  0.52 -1.06  1.27
# 4      23:27:29:8950 -0.42  0.96 -1.07  1.50
# ...              ...   ...   ...   ...   ...
# 17885  23:30:28:6830  1.75 -1.69 -0.26  2.45
# 17886  23:30:28:6919  1.87 -1.42 -0.43  2.38
# 17887  23:30:28:7020  1.52 -1.06 -0.83  2.03
# 17888  23:30:28:7200 -0.47  0.23 -1.02  1.14
# 17889  23:30:28:7210 -0.61  0.41 -0.98  1.22
#
# [17890 rows x 5 columns]

# %%
burpee['dates'] = pd.Timestamp('2022-08-22')
jump['dates'] = pd.Timestamp('2022-08-22')

burpee['time'] = pd.to_datetime(burpee['dates'].astype(str) + ' ' + burpee['time'].astype(str), format='%Y-%m-%d %H:%M:%S:%f')
jump['time'] = pd.to_datetime(jump['dates'].astype(str) + ' ' + jump['time'].astype(str), format='%Y-%m-%d %H:%M:%S:%f')

burpee
# Out:
#                             time    ax    ay    az   |a|      dates
# 0     2022-08-22 23:27:29.851000 -1.30 -0.08  1.80  2.22 2022-08-22
# 1     2022-08-22 23:27:29.861000 -1.03  0.09  1.22  1.60 2022-08-22
# 2     2022-08-22 23:27:29.867000 -0.77  0.28  0.03  0.82 2022-08-22
# 3     2022-08-22 23:27:29.878000 -0.47  0.52 -1.06  1.27 2022-08-22
# 4     2022-08-22 23:27:29.895000 -0.42  0.96 -1.07  1.50 2022-08-22
# ...                          ...   ...   ...   ...   ...        ...
# 17885 2022-08-22 23:30:28.683000  1.75 -1.69 -0.26  2.45 2022-08-22
# 17886 2022-08-22 23:30:28.691900  1.87 -1.42 -0.43  2.38 2022-08-22
# 17887 2022-08-22 23:30:28.702000  1.52 -1.06 -0.83  2.03 2022-08-22
# 17888 2022-08-22 23:30:28.720000 -0.47  0.23 -1.02  1.14 2022-08-22
# 17889 2022-08-22 23:30:28.721000 -0.61  0.41 -0.98  1.22 2022-08-22
#
# [17890 rows x 6 columns]

# %%
burpee.drop('dates', axis=1, inplace=True)
jump.drop('dates', axis=1, inplace=True)

# %%
burpee.head()
# Out:
#                      time    ax    ay    az   |a|
# 0 2022-08-22 23:27:29.851 -1.30 -0.08  1.80  2.22
# 1 2022-08-22 23:27:29.861 -1.03  0.09  1.22  1.60
# 2 2022-08-22 23:27:29.867 -0.77  0.28  0.03  0.82
# 3 2022-08-22 23:27:29.878 -0.47  0.52 -1.06  1.27
# 4 2022-08-22 23:27:29.895 -0.42  0.96 -1.07  1.50

# %% [markdown]
# ## Task 3: Visualising the Data

# %%
fig = plt.figure(figsize=(20,8))

a = plt.subplot(2, 2, 1)
a.set_title("time vs ax")
plt.plot(df_run['time'], df_run['ax'])

b = plt.subplot(2, 2, 2)
b.set_title("time vs ay")
plt.plot(df_run['time'], df_run['ay'])

c = plt.subplot(2, 2, 3)
c.set_title("time vs az")
plt.plot(df_run['time'], df_run['az'])

d = plt.subplot(2, 2, 4)
d.set_title("time vs |a|")
plt.plot(df_run['time'], df_run['|a|'])

plt.show()

# %% [markdown]
# Describe the raw data:
# What are the obvious differences between the signals recorded from the
# two different activities?
# Can you identify transition times at the beginning time respectively at
# the end of each recording?

# %% [markdown]
# ## Task 4: Preprocessing the Data

# %%
date1 = pd.Series(pd.date_range('00:00:00', periods = len(df_run.index), freq = 'L'))

df_run['delta_t'] = date1.dt.time

df_run
# Out:
#                             time    ax    ay    az   |a|          delta_t
# 0     2022-08-23 23:27:29.851000 -1.30 -0.08  1.80  2.22         00:00:00
# 1     2022-08-23 23:27:29.861000 -1.03  0.09  1.22  1.60  00:00:00.001000
# 2     2022-08-23 23:27:29.867000 -0.77  0.28  0.03  0.82  00:00:00.002000
# 3     2022-08-23 23:27:29.878000 -0.47  0.52 -1.06  1.27  00:00:00.003000
# 4     2022-08-23 23:27:29.895000 -0.42  0.96 -1.07  1.50  00:00:00.004000
# ...                          ...   ...   ...   ...   ...              ...
# 17885 2022-08-23 23:30:28.683000  1.75 -1.69 -0.26  2.45  00:00:17.885000
# 17886 2022-08-23 23:30:28.691900  1.87 -1.42 -0.43  2.38  00:00:17.886000
# 17887 2022-08-23 23:30:28.702000  1.52 -1.06 -0.83  2.03  00:00:17.887000
# 17888 2022-08-23 23:30:28.720000 -0.47  0.23 -1.02  1.14  00:00:17.888000
# 17889 2022-08-23 23:30:28.721000 -0.61  0.41 -0.98  1.22  00:00:17.889000
#
# [17890 rows x 6 columns]
